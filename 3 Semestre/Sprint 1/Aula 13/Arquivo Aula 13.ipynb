# %%
class Cliente:
    def __init__(self, nome: str, telefone: str):
        self.nome = nome
        self.telefone = telefone

ana = Cliente('Ana', '11 91111-1111') # Aba vira uma instancia da classe cliente
ana # Quero saber o quer o tem neste endereço de memoria
ana.nome # Quero saber o que tem dentro do atributo nome da classe deste endereço de memória

caique = Cliente('Caique', '11 91111-1111') # Aba vira uma instancia da classe cliente
arthur = Cliente('arthur', '11 91111-1111') # Aba vira uma instancia da classe cliente
kleber = Cliente('kleber', '11 91111-1111') # Aba vira uma instancia da classe cliente


print (ana.nome)
print(caique.nome)
# Out:
# Ana
# Caique

# %%
class Cliente:
    def __init__(self, nome: str, telefone: str):
        self.nome = nome
        self.telefone = telefone
    
    def __repr__(self) -> str:
        return f"Cliente(nome={self.nome}, telefone={self.telefone})"
    
    def resumo(self) -> str:
        return f"{self.nome} | tel; {self.telefone}"
    
ana = Cliente('Ana', '11 91111-1111')
ana
# Out:
# Cliente(nome=Ana, telefone=11 91111-1111)

# %% [markdown]
# Atividade Caique

# %%
# Missão 1

## Complete e execute os testes.

class Dispositivo:
    def __init__(self, nome: str, marca: str, sintoma: str):
        self.nome = nome
        self.marca = marca
        self.sintoma = sintoma

    def testar(self) -> str:
        return f"{self.nome} | {self.marca} | {self.sintoma}"

    def __repr__(self):
        return f"Seu nome é {self.nome} e sua marca é {self.marca} e você {self.sintoma!r}"

maquina_De_Lavar = Dispositivo("Maquina de Lavar", "Bastemp", "não lava e nem seca")
print(maquina_De_Lavar)
print(maquina_De_Lavar.testar())
# Out:
# Seu nome é Maquina de Lavar e sua marca é Bastemp e você 'não lava e nem seca'
# Maquina de Lavar | Bastemp | não lava e nem seca
