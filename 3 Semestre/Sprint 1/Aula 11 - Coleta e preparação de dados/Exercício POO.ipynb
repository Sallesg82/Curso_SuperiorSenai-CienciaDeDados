# %% [markdown]
# Classe 1

# %%
class Classeparte1:
    def __init__(self, nome: str, cpf: str):
        self.nome = nome
        self.cpf = cpf

kleber = Classeparte1('Kleber', '28574629401')

kleber

kleber.nome, kleber.cpf
# Out:
# ('Kleber', '28574629401')

# %% [markdown]
# Classe 2

# %%
class Classeparte2:
    def __init__(self, filme: str, personagem_principal: str):
        self.filme = filme
        self.persona = personagem_principal

duna = Classeparte2('Duna parte 1 e parte 2', 'Paul')

duna.filme, duna.persona
# Out:
# ('Duna parte 1 e parte 2', 'Paul')
